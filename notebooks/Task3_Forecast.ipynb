# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from pmdarima import auto_arima  # For ARIMA if needed
from statsmodels.tsa.arima.model import ARIMA  # Alternative manual ARIMA
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from statsmodels.tsa.stattools import adfuller  # If re-checking stationarity

# Load preprocessed TSLA data from Task 1 (adjust path if needed)
tsla = pd.read_csv('data/TSLA_historical.csv', index_col='Date', parse_dates=True)
tsla = tsla.ffill()  # Ensure no missing values
tsla['Adj Close Scaled'] = MinMaxScaler().fit_transform(tsla[['Adj Close']])  # Rescale if not done

# Define sequence length for LSTM (from Task 2)
seq_length = 60
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.preprocessing import MinMaxScaler
#       5 from pmdarima import auto_arima  # For ARIMA if needed
#       6 from statsmodels.tsa.arima.model import ARIMA  # Alternative manual ARIMA
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)    114     "compose",
#     115 ]
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\base.py:20
#      18 from .exceptions import InconsistentVersionWarning
#      19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#      22 from .utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from . import metadata_routing
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from ._indexing import (
#      17     _safe_indexing,  # noqa: F401
#      18     resample,
#      19     shuffle,
#      20 )
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\utils\validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\utils\_array_api.py:20
#      18 from ..externals import array_api_extra as xpx
#      19 from ..externals.array_api_compat import numpy as np_compat
# ---> 20 from .fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\sklearn\utils\fixes.py:16
#      14 import scipy
#      15 import scipy.sparse.linalg
# ---> 16 import scipy.stats
#      17 from scipy import optimize
#      19 try:
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\stats\_stats_py.py:40
#      37 from numpy import array, asarray, ma
#      39 from scipy import sparse
# ---> 40 from scipy.spatial import distance_matrix
#      42 from scipy.optimize import milp, LinearConstraint
#      43 from scipy._lib._util import (check_random_state, _get_nan,
#      44                               _rename_parameter, _contains_nan,
#      45                               normalize_axis_index, np_vecdot, AxisError)
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\spatial\__init__.py:110
#       1 """
#       2 =============================================================
#       3 Spatial algorithms and data structures (:mod:`scipy.spatial`)
#    (...)    107    QhullError
#     108 """  # noqa: E501
# --> 110 from ._kdtree import *
#     111 from ._ckdtree import *  # type: ignore[import-not-found]
#     112 from ._qhull import *
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\spatial\_kdtree.py:4
#       1 # Copyright Anne M. Archibald 2008
#       2 # Released under the scipy license
#       3 import numpy as np
# ----> 4 from ._ckdtree import cKDTree, cKDTreeNode  # type: ignore[import-not-found]
#       6 __all__ = ['minkowski_distance_p', 'minkowski_distance',
#       7            'distance_matrix',
#       8            'Rectangle', 'KDTree']
#      11 def minkowski_distance_p(x, y, p=2):
#
# File scipy/spatial/_ckdtree.pyx:12, in init scipy.spatial._ckdtree()
#
# ImportError: cannot import name copy_if_needed

# %%
# Retrain ARIMA on full data
model_arima = auto_arima(tsla['Adj Close'], seasonal=True, m=12, trace=True)
print(model_arima.summary())

# Save if needed (pmdarima supports pickling)
import pickle
with open('arima_model.pkl', 'wb') as f:
    pickle.dump(model_arima, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Retrain ARIMA on full data
# ----> 2 model_arima = auto_arima(tsla['Adj Close'], seasonal=True, m=12, trace=True)
#       3 print(model_arima.summary())
#       5 # Save if needed (pmdarima supports pickling)
#
# NameError: name 'auto_arima' is not defined

# %%
model_lstm = LSTMModel()
model_lstm.load_state_dict(torch.load('lstm_model.pth'))
model_lstm.eval()  # Set to evaluation mode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model_lstm = LSTMModel()
#       2 model_lstm.load_state_dict(torch.load('lstm_model.pth'))
#       3 model_lstm.eval()  # Set to evaluation mode
#
# NameError: name 'LSTMModel' is not defined

# %%
# Forecast with ARIMA
forecast_arima, stderr, conf_int = model_arima.predict(n_periods=365, return_conf_int=True, alpha=0.05)  # 95% CI
forecast_future = forecast_arima
forecast_lower = conf_int[:, 0]
forecast_upper = conf_int[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Forecast with ARIMA
# ----> 2 forecast_arima, stderr, conf_int = model_arima.predict(n_periods=365, return_conf_int=True, alpha=0.05)  # 95% CI
#       3 forecast_future = forecast_arima
#       4 forecast_lower = conf_int[:, 0]
#
# NameError: name 'model_arima' is not defined

# %%
# Generate future dates (business days, excluding weekends)
future_dates = pd.date_range(start=tsla.index[-1] + pd.Timedelta(days=1), periods=365, freq='B')

plt.figure(figsize=(14, 7))
plt.plot(tsla['Adj Close'], label='Historical Adj Close')
plt.plot(future_dates, forecast_future, label='Forecast Mean', color='orange')
plt.fill_between(future_dates, forecast_lower, forecast_upper, color='orange', alpha=0.3, label='95% Confidence Interval')
plt.title('TSLA Stock Price Forecast for Next 12 Months')
plt.xlabel('Date')
plt.ylabel('Adj Close Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Generate future dates (business days, excluding weekends)
# ----> 2 future_dates = pd.date_range(start=tsla.index[-1] + pd.Timedelta(days=1), periods=365, freq='B')
#       4 plt.figure(figsize=(14, 7))
#       5 plt.plot(tsla['Adj Close'], label='Historical Adj Close')
#
# NameError: name 'tsla' is not defined

# %%
import pandas as pd
import numpy as np
from pypfopt import expected_returns, risk_models, EfficientFrontier
import matplotlib.pyplot as plt

# Load cleaned data from Task 1 (Adj Close for all assets)
tsla = pd.read_csv('data/TSLA_historical.csv', index_col='Date', parse_dates=True)
bnd = pd.read_csv('data/BND_historical.csv', index_col='Date', parse_dates=True)
spy = pd.read_csv('data/SPY_historical.csv', index_col='Date', parse_dates=True)

# Compute daily returns for all assets
returns = pd.DataFrame({
    'TSLA': tsla['Adj Close'].pct_change(),
    'BND': bnd['Adj Close'].pct_change(),
    'SPY': spy['Adj Close'].pct_change()
}).dropna()  # Drop NaN from first row

# Historical expected returns for BND and SPY (annualized)
mu_bnd = returns['BND'].mean() * 252
mu_spy = returns['SPY'].mean() * 252

# For TSLA: Load forecast from Task 3 (assume saved as CSV; adjust if needed)
forecast_df = pd.read_csv('data/tsla_forecast.csv', index_col='Date', parse_dates=True)
forecast_returns = forecast_df['Forecast'].pct_change().dropna()
mu_tsla = forecast_returns.mean() * 252  # Annualized forecasted return

# Expected returns vector (order: TSLA, BND, SPY)
mu = np.array([mu_tsla, mu_bnd, mu_spy])

# Covariance matrix (annualized, using sample covariance)
cov_matrix = risk_models.sample_cov(returns) * 252  # PyPortfolioOpt's method; handles shrinkage for stability

print("Expected Returns:", mu)
print("Covariance Matrix:\n", cov_matrix)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\__init__.py:22
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\__init__.py:48
#      24     import sys
#      25     msg = """
#      26
#      27 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)     46 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      47         __version__, exc)
# ---> 48     raise ImportError(msg) from exc
#      49 finally:
#      50     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Scripts\python.exe"
#   * The NumPy version is: "1.23.5"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\__init__.py:22
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\__init__.py:48
#      24     import sys
#      25     msg = """
#      26
#      27 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)     46 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      47         __version__, exc)
# ---> 48     raise ImportError(msg) from exc
#      49 finally:
#      50     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Scripts\python.exe"
#   * The NumPy version is: "1.23.5"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from pypfopt import expected_returns, risk_models, EfficientFrontier
#       4 import matplotlib.pyplot as plt
#       6 # Load cleaned data from Task 1 (Adj Close for all assets)
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\pypfopt\__init__.py:1
# ----> 1 from .black_litterman import (
#       2     BlackLittermanModel,
#       3     market_implied_prior_returns,
#       4     market_implied_risk_aversion,
#       5 )
#       6 from .cla import CLA
#       7 from .discrete_allocation import DiscreteAllocation, get_latest_prices
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\pypfopt\black_litterman.py:16
#      13 import numpy as np
#      14 import pandas as pd
# ---> 16 from . import base_optimizer
#      19 def market_implied_prior_returns(
#      20     market_caps, risk_aversion, cov_matrix, risk_free_rate=0.0
#      21 ):
#      22     r"""
#      23     Compute the prior estimate of returns implied by the market weights.
#      24     In other words, given each asset's contribution to the risk of the market
#    (...)     42     :rtype: pd.Series
#      43     """
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\pypfopt\base_optimizer.py:17
#      14 from collections.abc import Iterable
#      15 from typing import List
# ---> 17 import cvxpy as cp
#      18 import numpy as np
#      19 import pandas as pd
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\__init__.py:19
#       1 """
#       2 Copyright, the CVXPY authors
#       3
#    (...)     14 limitations under the License.
#      15 """
#      16 from cvxpy.version import (
#      17     version as __version__,
#      18 )  # cvxpy/version.py is auto-generated
# ---> 19 from cvxpy.atoms import *
#      20 from cvxpy.constraints import (
#      21     Constraint as Constraint,
#      22     Cone as Cone,
#    (...)     33     FiniteSet as FiniteSet,
#      34 )
#      35 from cvxpy.error import (
#      36     DCPError as DCPError,
#      37     DGPError as DGPError,
#    (...)     42     warnings_enabled as warnings_enabled,
#      43 )
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\__init__.py:17
#       1 """
#       2 Copyright 2013 Steven Diamond
#       3
#    (...)     14 limitations under the License.
#      15 """
# ---> 17 from cvxpy.atoms.affine.binary_operators import (matmul, multiply,
#      18                                                  vdot, scalar_product, outer,)
#      19 from cvxpy.atoms.affine.bmat import bmat
#      20 from cvxpy.atoms.affine.broadcast_to import broadcast_to
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\affine\binary_operators.py:27
#      25 import cvxpy.lin_ops.lin_utils as lu
#      26 import cvxpy.utilities as u
# ---> 27 from cvxpy.atoms.affine.add_expr import AddExpression
#      28 from cvxpy.atoms.affine.affine_atom import AffAtom
#      29 from cvxpy.atoms.affine.conj import conj
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:23
#      21 import cvxpy.lin_ops.lin_utils as lu
#      22 import cvxpy.utilities as u
# ---> 23 from cvxpy.atoms.affine.affine_atom import AffAtom
#      24 from cvxpy.constraints.constraint import Constraint
#      25 from cvxpy.expressions.expression import Expression
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\affine\affine_atom.py:24
#      22 import cvxpy.utilities as u
#      23 from cvxpy.atoms.atom import Atom
# ---> 24 from cvxpy.cvxcore.python import canonInterface
#      25 from cvxpy.expressions.constants import Constant
#      26 from cvxpy.utilities import performance_utils as perf
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\cvxcore\python\canonInterface.py:25
#      23 import cvxpy.settings as s
#      24 from cvxpy.lin_ops import lin_op as lo
# ---> 25 from cvxpy.lin_ops.canon_backend import CanonBackend
#      28 def get_parameter_vector(param_size,
#      29                          param_id_to_col,
#      30                          param_id_to_size,
#      31                          param_id_to_value_fn,
#      32                          zero_offset: bool = False):
#      33     """Returns a flattened parameter vector
#      34
#      35     The flattened vector includes a constant offset (i.e, a 1).
#    (...)     48         A flattened NumPy array of parameter values, of length param_size + 1
#      49     """
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\lin_ops\canon_backend.py:25
#      23 import numpy as np
#      24 import scipy.sparse as sp
# ---> 25 from scipy.signal import convolve
#      27 import cvxpy.settings as s
#      28 from cvxpy.lin_ops import LinOp
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\signal\__init__.py:301
#       1 """
#       2 =======================================
#       3 Signal processing (:mod:`scipy.signal`)
#    (...)    295
#     296 """
#     297 # bring in the public functionality from private namespaces
#     298
#     299 # mypy: ignore-errors
# --> 301 from ._support_alternative_backends import *
#     302 from . import _support_alternative_backends
#     303 __all__ = _support_alternative_backends.__all__
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\signal\_support_alternative_backends.py:6
#       1 import functools
#       2 from scipy._lib._array_api import (
#       3     is_cupy, is_jax, scipy_namespace_for, SCIPY_ARRAY_API
#       4 )
# ----> 6 from ._signal_api import *   # noqa: F403
#       7 from . import _signal_api
#       8 from . import _delegators
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\signal\_signal_api.py:9
#       1 """This is the 'bare' scipy.signal API.
#       2
#       3 This --- private! --- module only collects implementations of public  API
#    (...)      6 re-exports decorated names to __init__.py
#       7 """
# ----> 9 from . import _sigtools, windows         # noqa: F401
#      10 from ._waveforms import *        # noqa: F403
#      11 from ._max_len_seq import max_len_seq       # noqa: F401
#
# ImportError: numpy._core.multiarray failed to import

# %%
# Initialize Efficient Frontier optimizer
ef = EfficientFrontier(mu, cov_matrix, weight_bounds=(0, 1))  # No short-selling

# Generate the Efficient Frontier by optimizing for multiple target returns
# (PyPortfolioOpt does this internally when plotting)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Initialize Efficient Frontier optimizer
# ----> 2 ef = EfficientFrontier(mu, cov_matrix, weight_bounds=(0, 1))  # No short-selling
#       4 # Generate the Efficient Frontier by optimizing for multiple target returns
#       5 # (PyPortfolioOpt does this internally when plotting)
#
# NameError: name 'EfficientFrontier' is not defined

# %%
from pypfopt import plotting

fig, ax = plt.subplots(figsize=(10, 6))
plotting.plot_efficient_frontier(ef, ax=ax, show_assets=True)  # Plots frontier and individual assets
ax.set_title('Efficient Frontier for TSLA, BND, SPY Portfolio')
ax.set_xlabel('Annualized Volatility (Risk)')
ax.set_ylabel('Annualized Expected Return')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\__init__.py:22
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\numpy\_core\__init__.py:48
#      24     import sys
#      25     msg = """
#      26
#      27 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)     46 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      47         __version__, exc)
# ---> 48     raise ImportError(msg) from exc
#      49 finally:
#      50     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Scripts\python.exe"
#   * The NumPy version is: "1.23.5"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from pypfopt import plotting
#       3 fig, ax = plt.subplots(figsize=(10, 6))
#       4 plotting.plot_efficient_frontier(ef, ax=ax, show_assets=True)  # Plots frontier and individual assets
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\pypfopt\__init__.py:1
# ----> 1 from .black_litterman import (
#       2     BlackLittermanModel,
#       3     market_implied_prior_returns,
#       4     market_implied_risk_aversion,
#       5 )
#       6 from .cla import CLA
#       7 from .discrete_allocation import DiscreteAllocation, get_latest_prices
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\pypfopt\black_litterman.py:16
#      13 import numpy as np
#      14 import pandas as pd
# ---> 16 from . import base_optimizer
#      19 def market_implied_prior_returns(
#      20     market_caps, risk_aversion, cov_matrix, risk_free_rate=0.0
#      21 ):
#      22     r"""
#      23     Compute the prior estimate of returns implied by the market weights.
#      24     In other words, given each asset's contribution to the risk of the market
#    (...)     42     :rtype: pd.Series
#      43     """
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\pypfopt\base_optimizer.py:17
#      14 from collections.abc import Iterable
#      15 from typing import List
# ---> 17 import cvxpy as cp
#      18 import numpy as np
#      19 import pandas as pd
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\__init__.py:19
#       1 """
#       2 Copyright, the CVXPY authors
#       3
#    (...)     14 limitations under the License.
#      15 """
#      16 from cvxpy.version import (
#      17     version as __version__,
#      18 )  # cvxpy/version.py is auto-generated
# ---> 19 from cvxpy.atoms import *
#      20 from cvxpy.constraints import (
#      21     Constraint as Constraint,
#      22     Cone as Cone,
#    (...)     33     FiniteSet as FiniteSet,
#      34 )
#      35 from cvxpy.error import (
#      36     DCPError as DCPError,
#      37     DGPError as DGPError,
#    (...)     42     warnings_enabled as warnings_enabled,
#      43 )
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\__init__.py:17
#       1 """
#       2 Copyright 2013 Steven Diamond
#       3
#    (...)     14 limitations under the License.
#      15 """
# ---> 17 from cvxpy.atoms.affine.binary_operators import (matmul, multiply,
#      18                                                  vdot, scalar_product, outer,)
#      19 from cvxpy.atoms.affine.bmat import bmat
#      20 from cvxpy.atoms.affine.broadcast_to import broadcast_to
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\affine\binary_operators.py:27
#      25 import cvxpy.lin_ops.lin_utils as lu
#      26 import cvxpy.utilities as u
# ---> 27 from cvxpy.atoms.affine.add_expr import AddExpression
#      28 from cvxpy.atoms.affine.affine_atom import AffAtom
#      29 from cvxpy.atoms.affine.conj import conj
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:23
#      21 import cvxpy.lin_ops.lin_utils as lu
#      22 import cvxpy.utilities as u
# ---> 23 from cvxpy.atoms.affine.affine_atom import AffAtom
#      24 from cvxpy.constraints.constraint import Constraint
#      25 from cvxpy.expressions.expression import Expression
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\atoms\affine\affine_atom.py:24
#      22 import cvxpy.utilities as u
#      23 from cvxpy.atoms.atom import Atom
# ---> 24 from cvxpy.cvxcore.python import canonInterface
#      25 from cvxpy.expressions.constants import Constant
#      26 from cvxpy.utilities import performance_utils as perf
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\cvxcore\python\canonInterface.py:25
#      23 import cvxpy.settings as s
#      24 from cvxpy.lin_ops import lin_op as lo
# ---> 25 from cvxpy.lin_ops.canon_backend import CanonBackend
#      28 def get_parameter_vector(param_size,
#      29                          param_id_to_col,
#      30                          param_id_to_size,
#      31                          param_id_to_value_fn,
#      32                          zero_offset: bool = False):
#      33     """Returns a flattened parameter vector
#      34
#      35     The flattened vector includes a constant offset (i.e, a 1).
#    (...)     48         A flattened NumPy array of parameter values, of length param_size + 1
#      49     """
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\cvxpy\lin_ops\canon_backend.py:25
#      23 import numpy as np
#      24 import scipy.sparse as sp
# ---> 25 from scipy.signal import convolve
#      27 import cvxpy.settings as s
#      28 from cvxpy.lin_ops import LinOp
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\signal\__init__.py:301
#       1 """
#       2 =======================================
#       3 Signal processing (:mod:`scipy.signal`)
#    (...)    295
#     296 """
#     297 # bring in the public functionality from private namespaces
#     298
#     299 # mypy: ignore-errors
# --> 301 from ._support_alternative_backends import *
#     302 from . import _support_alternative_backends
#     303 __all__ = _support_alternative_backends.__all__
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\signal\_support_alternative_backends.py:6
#       1 import functools
#       2 from scipy._lib._array_api import (
#       3     is_cupy, is_jax, scipy_namespace_for, SCIPY_ARRAY_API
#       4 )
# ----> 6 from ._signal_api import *   # noqa: F403
#       7 from . import _signal_api
#       8 from . import _delegators
#
# File c:\profileOptimization\TimeSeries-Portfolio-Optimization\env\Lib\site-packages\scipy\signal\_signal_api.py:9
#       1 """This is the 'bare' scipy.signal API.
#       2
#       3 This --- private! --- module only collects implementations of public  API
#    (...)      6 re-exports decorated names to __init__.py
#       7 """
# ----> 9 from . import _sigtools, windows         # noqa: F401
#      10 from ._waveforms import *        # noqa: F403
#      11 from ._max_len_seq import max_len_seq       # noqa: F401
#
# ImportError: numpy._core.multiarray failed to import
